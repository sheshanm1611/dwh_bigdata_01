# %%
# TO copy file from local workspace to volume
# Customer
dbutils.fs.cp("/Volumes/workspace/default/volume_data1/custs","/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_csv")
# To validate whether the file is copied successfully or not
display(dbutils.fs.ls("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_csv"))

#Usage
source_path="/Volumes/workspace/default/volume_data1/mobile_os_usgae.csv"
dest_path="/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage_tsv"
dbutils.fs.cp(source_path,dest_path)
# To validate whether the file is copied successfully or not
display(dbutils.fs.ls(dest_path))

# %%
source_path="/Volumes/workspace/default/volume_data1/Telecom/cust.csv"
dbutils.fs.cp(source_path,"/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_csv")

# To validate whether the file is copied successfully or not
display(dbutils.fs.ls(source_path))
display(dbutils.fs.ls("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_csv"))
