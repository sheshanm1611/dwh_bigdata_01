# %%
# %sql
select current_timestamp()

# %% [markdown]
# Created a child notebook

# %%
# %py 
import requests
var1 = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
var1.raise_for_status()

dbutils.fs.put("/Volumes/workspace/default/volume_data1/mobile_os_usgae.csv",var1.text,overwrite=True)
